# %%
name="Shruti"

# %%
name
# Out:
# 'Shruti'

# %%
name.upper()
# Out:
# 'SHRUTI'

# %%
name.isupper()
# Out:
# False

# %%
name.endswith("i")
# Out:
# True

# %%
name.find("S")
# Out:
# 0

# %%
len(name)
# Out:
# 6
